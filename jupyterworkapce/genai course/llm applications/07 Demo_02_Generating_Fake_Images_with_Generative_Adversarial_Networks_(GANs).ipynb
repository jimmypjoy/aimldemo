# %% [markdown]
# # __Demo: Generating Fake Images with Generative Adversarial Networks (GANs)__

# %% [markdown]
# # __Steps to Perform__
#
# Step 1: Import the Necessary Libraries
#
# Step 2: Load and Preprocess the Data
#
# Step 3: Build the Generator and Discriminator
#
# Step 4: Compile the Models
#
# Step 5: Train the Models
#
# Step 6: Execute the Training
#
# Step 7: Generate New Images and Evaluate the Model's Performance

# %% [markdown]
# # __Step 1: Import the Necessary Libraries__

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten
from tensorflow.keras.models import Sequential
import numpy as np

# %% [markdown]
# # __Step 2: Load and Preprocess the Data__
#
# - Load the MNIST dataset and preprocess it.
# - Preprocessing involves normalizing the data that can improve models' performance.

# %%
# Load MNIST data
(X_train, _), (_, _) = mnist.load_data()
# Normalize to between -1 and 1
X_train = (X_train.astype(np.float32) - 127.5) / 127.5
X_train = np.expand_dims(X_train, axis=3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# # __Step 3: Build the Generator and Discriminator__
#
# - Define the generator and discriminator models.
# - Generator takes a random noise vector as input and outputs an image.
# - Discriminator takes an image as input and outputs the probability of the image being real.

# %%
# Generator
def create_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=100, activation='relu'))
    model.add(Dense(512, activation='relu'))
    model.add(Dense(1024, activation='relu'))
    model.add(Dense(784, activation='tanh'))
    model.add(Reshape((28, 28, 1)))
    return model

# Discriminator
def create_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28, 1)))
    model.add(Dense(1024, activation='relu'))
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %% [markdown]
# # __Step 4: Compile the Models__
#
# - Compile the models, which involves defining the loss function and the optimizer.
# - The loss function evaluates the model's performance, while the optimizer aims to minimize the loss.

# %%
from tensorflow.keras.models import Sequential, Model

# Create and compile the discriminator
discriminator = create_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer='adam')

# Create and compile the generator
generator = create_generator()
generator.compile(loss='binary_crossentropy', optimizer='adam')

# Create and compile the combined model
discriminator.trainable = False
gan_input = Input(shape=(100,))
x = generator(gan_input)
gan_output = discriminator(x)
gan = Model(inputs=gan_input, outputs=gan_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # __Step 5: Train the Models__
#
# - Train the model, which involves feeding data into the models and adjusting the weights of the models based on the output.
# - The primary aim is for the generator to create images indistinguishable from real images by the discriminator.

# %%
def train(epochs=1, batch_size=128):
    # Load the data
    (X_train, _), (_, _) = mnist.load_data()
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5
    X_train = np.expand_dims(X_train, axis=3)

    # Labels for the batch size and the test size
    y_train_ones = np.ones((batch_size, 1))
    y_train_zeros = np.zeros((batch_size, 1))
    y_test_ones = np.ones((100, 1))

    # Start training
    for e in range(epochs):
        for i in range(X_train.shape[0] // batch_size):
            # Train Discriminator weights
            discriminator.trainable = True

            # Real samples
            X_batch = X_train[i*batch_size:(i+1)*batch_size]
            d_loss_real = discriminator.train_on_batch(x=X_batch, y=y_train_ones * (1 - 0.1 * np.random.rand(batch_size, 1)))

            # Fake Samples
            z_noise = np.random.normal(loc=0, scale=1, size=(batch_size, 100))
            X_fake = generator.predict_on_batch(z_noise)
            d_loss_fake = discriminator.train_on_batch(x=X_fake, y=y_train_zeros)

            # Discriminator loss
            d_loss = 0.5 * (d_loss_real + d_loss_fake)

            # Train Generator weights
            discriminator.trainable = False
            g_loss = gan.train_on_batch(x=z_noise, y=y_train_ones)

            print(f'Epoch: {e+1}, Batch: {i}, D Loss: {d_loss}, G Loss: {g_loss}')

# %% [markdown]
# # __Step 6: Execute the Training__

# %%
# Call the train function
train(epochs=50, batch_size=128)
# Out:
# Epoch: 1, Batch: 0, D Loss: 1.0030794143676758, G Loss: [array(1.0242786, dtype=float32), array(1.0242786, dtype=float32), array(1.0242786, dtype=float32)]
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7b50eff217e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7b50d7dd8f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch: 1, Batch: 1, D Loss: 1.0796834230422974, G Loss: [array(1.2552787, dtype=float32), array(1.2552787, dtype=float32), array(1.2552787, dtype=float32)]
# Epoch: 1, Batch: 2, D Loss: 1.1820800304412842, G Loss: [array(1.2682482, dtype=float32), array(1.2682482, dtype=float32), array(1.2682482, dtype=float32)]
# Epoch: 1, Batch: 3, D Loss: 1.0975069999694824, G Loss: [array(1.0727658, dtype=float32), array(1.0727658, dtype=float32), array(1.0727658, dtype=float32)]
# Epoch: 1, Batch: 4, D Loss: 1.1393296718597412, G Loss: [array(1.1029236, dtype=float32), array(1.1029236, dtype=float32), array(1.1029236, dtype=float32)]
# Epoch: 1, Batch: 5, D Loss: 1.0265460014343262, G Loss: [array(1.0218507, dtype=float32), array(1.0218507, dtype=float32), array(1.0218507, dtype=float32)]
# Epoch: 1, Batch: 6, D Loss: 0.9586465954780579, G Loss: [array(0.95894545, dtype=float32), array(0.95894545, dtype=float32), array(0.95894545, dtype=float32)]
# Epoch: 1, Batch: 7, D Loss: 0.898357629776001, G Loss: [array(0.88846296, dtype=float32), array(0.88846296, dtype=float32), array(0.88846296, dtype=float32)]
# Epoch: 1, Batch: 8, D Loss: 0.8396438360214233, G Loss: [array(0.82527715, dtype=float32), array(0.82527715, dtype=float32), array(0.82527715, dtype=float32)]
# Epoch: 1, Batch: 9, D Loss: 0.7939029932022095, G Loss: [array(0.7816235, dtype=float32), array(0.7816235, dtype=float32), array(0.7816235, dtype=float32)]
# Epoch: 1, Batch: 10, D Loss: 0.7468690872192383, G Loss: [array(0.7377209, dtype=float32), array(0.7377209, dtype=float32), array(0.7377209, dtype=float32)]
# Epoch: 1, Batch: 11, D Loss: 0.7049990892410278, G Loss: [array(0.6961868, dtype=float32), array(0.6961868, dtype=float32), array(0.6961868, dtype=float32)]
# Epoch: 1, Batch: 12, D Loss: 0.6669946908950806, G Loss: [array(0.65733904, dtype=float32), array(0.65733904, dtype=float32), array(0.65733904, dtype=float32)]
# Epoch: 1, Batch: 13, D Loss: 0.6324732303619385, G Loss: [array(0.6231796, dtype=float32), array(0.6231796, dtype=float32), array(0.6231796, dtype=float32)]
# Epoch: 1, Batch: 14, D Loss: 0.6013821363449097, G Loss: [array(0.5932068, dtype=float32), array(0.5932068, dtype=float32), array(0.5932068, dtype=float32)]
# Epoch: 1, Batch: 15, D Loss: 0.5734540224075317, G Loss: [array(0.56652147, dtype=float32), array(0.56652147, dtype=float32), array(0.56652147, dtype=float32)]
# Epoch: 1, Batch: 16, D Loss: 0.5501769185066223, G Loss: [array(0.5441344, dtype=float32), array(0.5441344, dtype=float32), array(0.5441344, dtype=float32)]
# Epoch: 1, Batch: 17, D Loss: 0.5295242071151733, G Loss: [array(0.5241695, dtype=float32), array(0.5241695, dtype=float32), array(0.5241695, dtype=float32)]
# Epoch: 1, Batch: 18, D Loss: 0.51424241065979, G Loss: [array(0.5099718, dtype=float32), array(0.5099718, dtype=float32), array(0.5099718, dtype=float32)]
# Epoch: 1, Batch: 19, D Loss: 0.5003558993339539, G Loss: [array(0.49727282, dtype=float32), array(0.49727282, dtype=float32), array(0.49727282, dtype=float32)]
# Epoch: 1, Batch: 20, D Loss: 0.4893650412559509, G Loss: [array(0.4869338, dtype=float32), array(0.4869338, dtype=float32), array(0.4869338, dtype=float32)]
# Epoch: 1, Batch: 21, D Loss: 0.4794205129146576, G Loss: [array(0.4774314, dtype=float32), array(0.4774314, dtype=float32), array(0.4774314, dtype=float32)]
# Epoch: 1, Batch: 22, D Loss: 0.4733918607234955, G Loss: [array(0.47221893, dtype=float32), array(0.47221893, dtype=float32), array(0.47221893, dtype=float32)]
# Epoch: 1, Batch: 23, D Loss: 0.46852022409439087, G Loss: [array(0.46866322, dtype=float32), array(0.46866322, dtype=float32), array(0.46866322, dtype=float32)]
# Epoch: 1, Batch: 24, D Loss: 0.46681857109069824, G Loss: [array(0.46781063, dtype=float32), array(0.46781063, dtype=float32), array(0.46781063, dtype=float32)]
# Epoch: 1, Batch: 25, D Loss: 0.4648539423942566, G Loss: [array(0.46623355, dtype=float32), array(0.46623355, dtype=float32), array(0.46623355, dtype=float32)]
# Epoch: 1, Batch: 26, D Loss: 0.46486538648605347, G Loss: [array(0.4667505, dtype=float32), array(0.4667505, dtype=float32), array(0.4667505, dtype=float32)]
# Epoch: 1, Batch: 27, D Loss: 0.46443140506744385, G Loss: [array(0.46670642, dtype=float32), array(0.46670642, dtype=float32), array(0.46670642, dtype=float32)]
# Epoch: 1, Batch: 28, D Loss: 0.464152991771698, G Loss: [array(0.46607694, dtype=float32), array(0.46607694, dtype=float32), array(0.46607694, dtype=float32)]
# Epoch: 1, Batch: 29, D Loss: 0.4626985788345337, G Loss: [array(0.46353066, dtype=float32), array(0.46353066, dtype=float32), array(0.46353066, dtype=float32)]
# Epoch: 1, Batch: 30, D Loss: 0.46087026596069336, G Loss: [array(0.4607939, dtype=float32), array(0.4607939, dtype=float32), array(0.4607939, dtype=float32)]
# Epoch: 1, Batch: 31, D Loss: 0.45619508624076843, G Loss: [array(0.4553457, dtype=float32), array(0.4553457, dtype=float32), array(0.4553457, dtype=float32)]
# Epoch: 1, Batch: 32, D Loss: 0.45052653551101685, G Loss: [array(0.4486885, dtype=float32), array(0.4486885, dtype=float32), array(0.4486885, dtype=float32)]
# Epoch: 1, Batch: 33, D Loss: 0.4426571726799011, G Loss: [array(0.44029433, dtype=float32), array(0.44029433, dtype=float32), array(0.44029433, dtype=float32)]
# Epoch: 1, Batch: 34, D Loss: 0.44241803884506226, G Loss: [array(0.44023657, dtype=float32), array(0.44023657, dtype=float32), array(0.44023657, dtype=float32)]
# Epoch: 1, Batch: 35, D Loss: 0.43890437483787537, G Loss: [array(0.43787396, dtype=float32), array(0.43787396, dtype=float32), array(0.43787396, dtype=float32)]
# Epoch: 1, Batch: 36, D Loss: 0.4411528408527374, G Loss: [array(0.44134048, dtype=float32), array(0.44134048, dtype=float32), array(0.44134048, dtype=float32)]
# Epoch: 1, Batch: 37, D Loss: 0.44534415006637573, G Loss: [array(0.44608235, dtype=float32), array(0.44608235, dtype=float32), array(0.44608235, dtype=float32)]
# Epoch: 1, Batch: 38, D Loss: 0.44897985458374023, G Loss: [array(0.44942656, dtype=float32), array(0.44942656, dtype=float32), array(0.44942656, dtype=float32)]
# Epoch: 1, Batch: 39, D Loss: 0.44913849234580994, G Loss: [array(0.44884467, dtype=float32), array(0.44884467, dtype=float32), array(0.44884467, dtype=float32)]
# Epoch: 1, Batch: 40, D Loss: 0.4453023672103882, G Loss: [array(0.44435427, dtype=float32), array(0.44435427, dtype=float32), array(0.44435427, dtype=float32)]
# Epoch: 1, Batch: 41, D Loss: 0.4783608615398407, G Loss: [array(0.4777714, dtype=float32), array(0.4777714, dtype=float32), array(0.4777714, dtype=float32)]
# Epoch: 1, Batch: 42, D Loss: 0.4761597514152527, G Loss: [array(0.4769513, dtype=float32), array(0.4769513, dtype=float32), array(0.4769513, dtype=float32)]
# Epoch: 1, Batch: 43, D Loss: 0.47930511832237244, G Loss: [array(0.48050168, dtype=float32), array(0.48050168, dtype=float32), array(0.48050168, dtype=float32)]
# Epoch: 1, Batch: 44, D Loss: 0.4823489785194397, G Loss: [array(0.48322454, dtype=float32), array(0.48322454, dtype=float32), array(0.48322454, dtype=float32)]
# Epoch: 1, Batch: 45, D Loss: 0.4841958284378052, G Loss: [array(0.48438287, dtype=float32), array(0.48438287, dtype=float32), array(0.48438287, dtype=float32)]
# Epoch: 1, Batch: 46, D Loss: 0.4844852089881897, G Loss: [array(0.48397622, dtype=float32), array(0.48397622, dtype=float32), array(0.48397622, dtype=float32)]
# Epoch: 1, Batch: 47, D Loss: 0.4823223352432251, G Loss: [array(0.48144057, dtype=float32), array(0.48144057, dtype=float32), array(0.48144057, dtype=float32)]
# Epoch: 1, Batch: 48, D Loss: 0.47760969400405884, G Loss: [array(0.47657877, dtype=float32), array(0.47657877, dtype=float32), array(0.47657877, dtype=float32)]
# Epoch: 1, Batch: 49, D Loss: 0.492059588432312, G Loss: [array(0.49126747, dtype=float32), array(0.49126747, dtype=float32), array(0.49126747, dtype=float32)]
# Epoch: 1, Batch: 50, D Loss: 0.4896610379219055, G Loss: [array(0.4896394, dtype=float32), array(0.4896394, dtype=float32), array(0.4896394, dtype=float32)]
# Epoch: 1, Batch: 51, D Loss: 0.4916137456893921, G Loss: [array(0.4920077, dtype=float32), array(0.4920077, dtype=float32), array(0.4920077, dtype=float32)]
# Epoch: 1, Batch: 52, D Loss: 0.49465644359588623, G Loss: [array(0.49502495, dtype=float32), array(0.49502495, dtype=float32), array(0.49502495, dtype=float32)]
# Epoch: 1, Batch: 53, D Loss: 0.49714016914367676, G Loss: [array(0.49723518, dtype=float32), array(0.49723518, dtype=float32), array(0.49723518, dtype=float32)]
# Epoch: 1, Batch: 54, D Loss: 0.49965137243270874, G Loss: [array(0.49963257, dtype=float32), array(0.49963257, dtype=float32), array(0.49963257, dtype=float32)]
# Epoch: 1, Batch: 55, D Loss: 0.5010101199150085, G Loss: [array(0.5005677, dtype=float32), array(0.5005677, dtype=float32), array(0.5005677, dtype=float32)]
# Epoch: 1, Batch: 56, D Loss: 0.4999126195907593, G Loss: [array(0.49906728, dtype=float32), array(0.49906728, dtype=float32), array(0.49906728, dtype=float32)]
# Epoch: 1, Batch: 57, D Loss: 0.49659550189971924, G Loss: [array(0.49537182, dtype=float32), array(0.49537182, dtype=float32), array(0.49537182, dtype=float32)]
# Epoch: 1, Batch: 58, D Loss: 0.4947400689125061, G Loss: [array(0.4934562, dtype=float32), array(0.4934562, dtype=float32), array(0.4934562, dtype=float32)]
# Epoch: 1, Batch: 59, D Loss: 0.49082931876182556, G Loss: [array(0.4896724, dtype=float32), array(0.4896724, dtype=float32), array(0.4896724, dtype=float32)]
# Epoch: 1, Batch: 60, D Loss: 0.48797160387039185, G Loss: [array(0.4869152, dtype=float32), array(0.4869152, dtype=float32), array(0.4869152, dtype=float32)]
# Epoch: 1, Batch: 61, D Loss: 0.48539185523986816, G Loss: [array(0.4843846, dtype=float32), array(0.4843846, dtype=float32), array(0.4843846, dtype=float32)]
# Epoch: 1, Batch: 62, D Loss: 0.48287802934646606, G Loss: [array(0.48184347, dtype=float32), array(0.48184347, dtype=float32), array(0.48184347, dtype=float32)]
# Epoch: 1, Batch: 63, D Loss: 0.47985196113586426, G Loss: [array(0.47872034, dtype=float32), array(0.47872034, dtype=float32), array(0.47872034, dtype=float32)]
# Epoch: 1, Batch: 64, D Loss: 0.47579455375671387, G Loss: [array(0.47452915, dtype=float32), array(0.47452915, dtype=float32), array(0.47452915, dtype=float32)]
# Epoch: 1, Batch: 65, D Loss: 0.4717382490634918, G Loss: [array(0.47044423, dtype=float32), array(0.47044423, dtype=float32), array(0.47044423, dtype=float32)]
# Epoch: 1, Batch: 66, D Loss: 0.46739885210990906, G Loss: [array(0.46619573, dtype=float32), array(0.46619573, dtype=float32), array(0.46619573, dtype=float32)]
# Epoch: 1, Batch: 67, D Loss: 0.46315324306488037, G Loss: [array(0.46204045, dtype=float32), array(0.46204045, dtype=float32), array(0.46204045, dtype=float32)]
# Epoch: 1, Batch: 68, D Loss: 0.45906996726989746, G Loss: [array(0.45800394, dtype=float32), array(0.45800394, dtype=float32), array(0.45800394, dtype=float32)]
# Epoch: 1, Batch: 69, D Loss: 0.45503920316696167, G Loss: [array(0.45397657, dtype=float32), array(0.45397657, dtype=float32), array(0.45397657, dtype=float32)]
# Epoch: 1, Batch: 70, D Loss: 0.45181310176849365, G Loss: [array(0.45092994, dtype=float32), array(0.45092994, dtype=float32), array(0.45092994, dtype=float32)]
# Epoch: 1, Batch: 71, D Loss: 0.44900596141815186, G Loss: [array(0.44842598, dtype=float32), array(0.44842598, dtype=float32), array(0.44842598, dtype=float32)]
# Epoch: 1, Batch: 72, D Loss: 0.4467121958732605, G Loss: [array(0.44614944, dtype=float32), array(0.44614944, dtype=float32), array(0.44614944, dtype=float32)]
# Epoch: 1, Batch: 73, D Loss: 0.44414976239204407, G Loss: [array(0.44335282, dtype=float32), array(0.44335282, dtype=float32), array(0.44335282, dtype=float32)]
# Epoch: 1, Batch: 74, D Loss: 0.4407520592212677, G Loss: [array(0.43968287, dtype=float32), array(0.43968287, dtype=float32), array(0.43968287, dtype=float32)]
# Epoch: 1, Batch: 75, D Loss: 0.4370045065879822, G Loss: [array(0.43577838, dtype=float32), array(0.43577838, dtype=float32), array(0.43577838, dtype=float32)]
# Epoch: 1, Batch: 76, D Loss: 0.43368804454803467, G Loss: [array(0.43243834, dtype=float32), array(0.43243834, dtype=float32), array(0.43243834, dtype=float32)]
# Epoch: 1, Batch: 77, D Loss: 0.4296574592590332, G Loss: [array(0.42844132, dtype=float32), array(0.42844132, dtype=float32), array(0.42844132, dtype=float32)]
# Epoch: 1, Batch: 78, D Loss: 0.42602473497390747, G Loss: [array(0.42482993, dtype=float32), array(0.42482993, dtype=float32), array(0.42482993, dtype=float32)]
# Epoch: 1, Batch: 79, D Loss: 0.42251425981521606, G Loss: [array(0.4213304, dtype=float32), array(0.4213304, dtype=float32), array(0.4213304, dtype=float32)]
# Epoch: 1, Batch: 80, D Loss: 0.4189453423023224, G Loss: [array(0.41776618, dtype=float32), array(0.41776618, dtype=float32), array(0.41776618, dtype=float32)]
# Epoch: 1, Batch: 81, D Loss: 0.41530323028564453, G Loss: [array(0.4141314, dtype=float32), array(0.4141314, dtype=float32), array(0.4141314, dtype=float32)]
# Epoch: 1, Batch: 82, D Loss: 0.41173726320266724, G Loss: [array(0.41058746, dtype=float32), array(0.41058746, dtype=float32), array(0.41058746, dtype=float32)]
# Epoch: 1, Batch: 83, D Loss: 0.4083407521247864, G Loss: [array(0.40723413, dtype=float32), array(0.40723413, dtype=float32), array(0.40723413, dtype=float32)]
# Epoch: 1, Batch: 84, D Loss: 0.40502750873565674, G Loss: [array(0.40398034, dtype=float32), array(0.40398034, dtype=float32), array(0.40398034, dtype=float32)]
# Epoch: 1, Batch: 85, D Loss: 0.4018629491329193, G Loss: [array(0.4008542, dtype=float32), array(0.4008542, dtype=float32), array(0.4008542, dtype=float32)]
# Epoch: 1, Batch: 86, D Loss: 0.3987060785293579, G Loss: [array(0.39771447, dtype=float32), array(0.39771447, dtype=float32), array(0.39771447, dtype=float32)]
# Epoch: 1, Batch: 87, D Loss: 0.3956246078014374, G Loss: [array(0.39462185, dtype=float32), array(0.39462185, dtype=float32), array(0.39462185, dtype=float32)]
# Epoch: 1, Batch: 88, D Loss: 0.39250606298446655, G Loss: [array(0.39147624, dtype=float32), array(0.39147624, dtype=float32), array(0.39147624, dtype=float32)]
# Epoch: 1, Batch: 89, D Loss: 0.38939064741134644, G Loss: [array(0.38835743, dtype=float32), array(0.38835743, dtype=float32), array(0.38835743, dtype=float32)]
# Epoch: 1, Batch: 90, D Loss: 0.38635703921318054, G Loss: [array(0.38533306, dtype=float32), array(0.38533306, dtype=float32), array(0.38533306, dtype=float32)]
# Epoch: 1, Batch: 91, D Loss: 0.3833249807357788, G Loss: [array(0.38231152, dtype=float32), array(0.38231152, dtype=float32), array(0.38231152, dtype=float32)]
# Epoch: 1, Batch: 92, D Loss: 0.38028812408447266, G Loss: [array(0.37928477, dtype=float32), array(0.37928477, dtype=float32), array(0.37928477, dtype=float32)]
# Epoch: 1, Batch: 93, D Loss: 0.37726718187332153, G Loss: [array(0.376276, dtype=float32), array(0.376276, dtype=float32), array(0.376276, dtype=float32)]
# Epoch: 1, Batch: 94, D Loss: 0.37436428666114807, G Loss: [array(0.37338698, dtype=float32), array(0.37338698, dtype=float32), array(0.37338698, dtype=float32)]
# Epoch: 1, Batch: 95, D Loss: 0.37153035402297974, G Loss: [array(0.37056854, dtype=float32), array(0.37056854, dtype=float32), array(0.37056854, dtype=float32)]
# Epoch: 1, Batch: 96, D Loss: 0.36872488260269165, G Loss: [array(0.36777937, dtype=float32), array(0.36777937, dtype=float32), array(0.36777937, dtype=float32)]
# Epoch: 1, Batch: 97, D Loss: 0.36591631174087524, G Loss: [array(0.36498696, dtype=float32), array(0.36498696, dtype=float32), array(0.36498696, dtype=float32)]
# Epoch: 1, Batch: 98, D Loss: 0.3632698655128479, G Loss: [array(0.3623559, dtype=float32), array(0.3623559, dtype=float32), array(0.3623559, dtype=float32)]
# Epoch: 1, Batch: 99, D Loss: 0.3607197403907776, G Loss: [array(0.35982054, dtype=float32), array(0.35982054, dtype=float32), array(0.35982054, dtype=float32)]
# Epoch: 1, Batch: 100, D Loss: 0.3581741452217102, G Loss: [array(0.3572898, dtype=float32), array(0.3572898, dtype=float32), array(0.3572898, dtype=float32)]
# Epoch: 1, Batch: 101, D Loss: 0.35570770502090454, G Loss: [array(0.35483906, dtype=float32), array(0.35483906, dtype=float32), array(0.35483906, dtype=float32)]
# Epoch: 1, Batch: 102, D Loss: 0.3533179759979248, G Loss: [array(0.35246614, dtype=float32), array(0.35246614, dtype=float32), array(0.35246614, dtype=float32)]
# Epoch: 1, Batch: 103, D Loss: 0.3508865237236023, G Loss: [array(0.35005257, dtype=float32), array(0.35005257, dtype=float32), array(0.35005257, dtype=float32)]
# Epoch: 1, Batch: 104, D Loss: 0.34851396083831787, G Loss: [array(0.3476976, dtype=float32), array(0.3476976, dtype=float32), array(0.3476976, dtype=float32)]
# Epoch: 1, Batch: 105, D Loss: 0.346211314201355, G Loss: [array(0.3454091, dtype=float32), array(0.3454091, dtype=float32), array(0.3454091, dtype=float32)]
# Epoch: 1, Batch: 106, D Loss: 0.34390586614608765, G Loss: [array(0.34311408, dtype=float32), array(0.34311408, dtype=float32), array(0.34311408, dtype=float32)]
# Epoch: 1, Batch: 107, D Loss: 0.34172534942626953, G Loss: [array(0.34094384, dtype=float32), array(0.34094384, dtype=float32), array(0.34094384, dtype=float32)]
# Epoch: 1, Batch: 108, D Loss: 0.3395547866821289, G Loss: [array(0.33878613, dtype=float32), array(0.33878613, dtype=float32), array(0.33878613, dtype=float32)]
# Epoch: 1, Batch: 109, D Loss: 0.3373110890388489, G Loss: [array(0.33655953, dtype=float32), array(0.33655953, dtype=float32), array(0.33655953, dtype=float32)]
# Epoch: 1, Batch: 110, D Loss: 0.3352271318435669, G Loss: [array(0.33448732, dtype=float32), array(0.33448732, dtype=float32), array(0.33448732, dtype=float32)]
# Epoch: 1, Batch: 111, D Loss: 0.3331293761730194, G Loss: [array(0.3323972, dtype=float32), array(0.3323972, dtype=float32), array(0.3323972, dtype=float32)]
# Epoch: 1, Batch: 112, D Loss: 0.331149697303772, G Loss: [array(0.33043364, dtype=float32), array(0.33043364, dtype=float32), array(0.33043364, dtype=float32)]
# Epoch: 1, Batch: 113, D Loss: 0.3291826844215393, G Loss: [array(0.32849047, dtype=float32), array(0.32849047, dtype=float32), array(0.32849047, dtype=float32)]
# Epoch: 1, Batch: 114, D Loss: 0.32726728916168213, G Loss: [array(0.32663766, dtype=float32), array(0.32663766, dtype=float32), array(0.32663766, dtype=float32)]
# Epoch: 1, Batch: 115, D Loss: 0.3262403905391693, G Loss: [array(0.32609922, dtype=float32), array(0.32609922, dtype=float32), array(0.32609922, dtype=float32)]
# Epoch: 1, Batch: 116, D Loss: 0.3263671398162842, G Loss: [array(0.32702518, dtype=float32), array(0.32702518, dtype=float32), array(0.32702518, dtype=float32)]
# Epoch: 1, Batch: 117, D Loss: 0.3272903561592102, G Loss: [array(0.3278862, dtype=float32), array(0.3278862, dtype=float32), array(0.3278862, dtype=float32)]
# Epoch: 1, Batch: 118, D Loss: 0.32722437381744385, G Loss: [array(0.3270978, dtype=float32), array(0.3270978, dtype=float32), array(0.3270978, dtype=float32)]
# Epoch: 1, Batch: 119, D Loss: 0.3263360261917114, G Loss: [array(0.32568246, dtype=float32), array(0.32568246, dtype=float32), array(0.32568246, dtype=float32)]
# Epoch: 1, Batch: 120, D Loss: 0.32537639141082764, G Loss: [array(0.32471067, dtype=float32), array(0.32471067, dtype=float32), array(0.32471067, dtype=float32)]
# Epoch: 1, Batch: 121, D Loss: 0.32367733120918274, G Loss: [array(0.32314306, dtype=float32), array(0.32314306, dtype=float32), array(0.32314306, dtype=float32)]
# Epoch: 1, Batch: 122, D Loss: 0.32227057218551636, G Loss: [array(0.3218031, dtype=float32), array(0.3218031, dtype=float32), array(0.3218031, dtype=float32)]
# Epoch: 1, Batch: 123, D Loss: 0.32581645250320435, G Loss: [array(0.32811284, dtype=float32), array(0.32811284, dtype=float32), array(0.32811284, dtype=float32)]
# Epoch: 1, Batch: 124, D Loss: 0.3323347866535187, G Loss: [array(0.33651522, dtype=float32), array(0.33651522, dtype=float32), array(0.33651522, dtype=float32)]
# Epoch: 1, Batch: 125, D Loss: 0.33751046657562256, G Loss: [array(0.3388215, dtype=float32), array(0.3388215, dtype=float32), array(0.3388215, dtype=float32)]
# Epoch: 1, Batch: 126, D Loss: 0.3383009731769562, G Loss: [array(0.33766398, dtype=float32), array(0.33766398, dtype=float32), array(0.33766398, dtype=float32)]
# Epoch: 1, Batch: 127, D Loss: 0.34491512179374695, G Loss: [array(0.34437245, dtype=float32), array(0.34437245, dtype=float32), array(0.34437245, dtype=float32)]
# Epoch: 1, Batch: 128, D Loss: 0.3456885516643524, G Loss: [array(0.3469271, dtype=float32), array(0.3469271, dtype=float32), array(0.3469271, dtype=float32)]
# Epoch: 1, Batch: 129, D Loss: 0.3479764461517334, G Loss: [array(0.3495845, dtype=float32), array(0.3495845, dtype=float32), array(0.3495845, dtype=float32)]
# Epoch: 1, Batch: 130, D Loss: 0.34929996728897095, G Loss: [array(0.34935504, dtype=float32), array(0.34935504, dtype=float32), array(0.34935504, dtype=float32)]
# Epoch: 1, Batch: 131, D Loss: 0.3503887951374054, G Loss: [array(0.35002026, dtype=float32), array(0.35002026, dtype=float32), array(0.35002026, dtype=float32)]
# Epoch: 1, Batch: 132, D Loss: 0.3515109717845917, G Loss: [array(0.35123247, dtype=float32), array(0.35123247, dtype=float32), array(0.35123247, dtype=float32)]
# Epoch: 1, Batch: 133, D Loss: 0.3511205315589905, G Loss: [array(0.35112897, dtype=float32), array(0.35112897, dtype=float32), array(0.35112897, dtype=float32)]
# Epoch: 1, Batch: 134, D Loss: 0.35033267736434937, G Loss: [array(0.35000387, dtype=float32), array(0.35000387, dtype=float32), array(0.35000387, dtype=float32)]
# Epoch: 1, Batch: 135, D Loss: 0.34898269176483154, G Loss: [array(0.3483923, dtype=float32), array(0.3483923, dtype=float32), array(0.3483923, dtype=float32)]
# Epoch: 1, Batch: 136, D Loss: 0.3474346995353699, G Loss: [array(0.34680456, dtype=float32), array(0.34680456, dtype=float32), array(0.34680456, dtype=float32)]
# Epoch: 1, Batch: 137, D Loss: 0.3460775911808014, G Loss: [array(0.34546134, dtype=float32), array(0.34546134, dtype=float32), array(0.34546134, dtype=float32)]
# Epoch: 1, Batch: 138, D Loss: 0.34456107020378113, G Loss: [array(0.3440981, dtype=float32), array(0.3440981, dtype=float32), array(0.3440981, dtype=float32)]
# Epoch: 1, Batch: 139, D Loss: 0.34306836128234863, G Loss: [array(0.34247202, dtype=float32), array(0.34247202, dtype=float32), array(0.34247202, dtype=float32)]
# Epoch: 1, Batch: 140, D Loss: 0.34144049882888794, G Loss: [array(0.34083766, dtype=float32), array(0.34083766, dtype=float32), array(0.34083766, dtype=float32)]
# Epoch: 1, Batch: 141, D Loss: 0.34012192487716675, G Loss: [array(0.3396112, dtype=float32), array(0.3396112, dtype=float32), array(0.3396112, dtype=float32)]
# Epoch: 1, Batch: 142, D Loss: 0.3388413190841675, G Loss: [array(0.33846956, dtype=float32), array(0.33846956, dtype=float32), array(0.33846956, dtype=float32)]
# Epoch: 1, Batch: 143, D Loss: 0.337706983089447, G Loss: [array(0.33711988, dtype=float32), array(0.33711988, dtype=float32), array(0.33711988, dtype=float32)]
# Epoch: 1, Batch: 144, D Loss: 0.33765602111816406, G Loss: [array(0.33715144, dtype=float32), array(0.33715144, dtype=float32), array(0.33715144, dtype=float32)]
# Epoch: 1, Batch: 145, D Loss: 0.3433050513267517, G Loss: [array(0.34954602, dtype=float32), array(0.34954602, dtype=float32), array(0.34954602, dtype=float32)]
# Epoch: 1, Batch: 146, D Loss: 0.34855085611343384, G Loss: [array(0.34795713, dtype=float32), array(0.34795713, dtype=float32), array(0.34795713, dtype=float32)]
# Epoch: 1, Batch: 147, D Loss: 0.3543412983417511, G Loss: [array(0.35374174, dtype=float32), array(0.35374174, dtype=float32), array(0.35374174, dtype=float32)]
# Epoch: 1, Batch: 148, D Loss: 0.3541565537452698, G Loss: [array(0.35360265, dtype=float32), array(0.35360265, dtype=float32), array(0.35360265, dtype=float32)]
# Epoch: 1, Batch: 149, D Loss: 0.35385414958000183, G Loss: [array(0.35460722, dtype=float32), array(0.35460722, dtype=float32), array(0.35460722, dtype=float32)]
# Epoch: 1, Batch: 150, D Loss: 0.35401779413223267, G Loss: [array(0.35394084, dtype=float32), array(0.35394084, dtype=float32), array(0.35394084, dtype=float32)]
# Epoch: 1, Batch: 151, D Loss: 0.353058785200119, G Loss: [array(0.35255197, dtype=float32), array(0.35255197, dtype=float32), array(0.35255197, dtype=float32)]
# Epoch: 1, Batch: 152, D Loss: 0.3519971966743469, G Loss: [array(0.35144266, dtype=float32), array(0.35144266, dtype=float32), array(0.35144266, dtype=float32)]
# Epoch: 1, Batch: 153, D Loss: 0.35101231932640076, G Loss: [array(0.35046238, dtype=float32), array(0.35046238, dtype=float32), array(0.35046238, dtype=float32)]
# Epoch: 1, Batch: 154, D Loss: 0.3496374785900116, G Loss: [array(0.3491291, dtype=float32), array(0.3491291, dtype=float32), array(0.3491291, dtype=float32)]
# Epoch: 1, Batch: 155, D Loss: 0.3483508229255676, G Loss: [array(0.3480342, dtype=float32), array(0.3480342, dtype=float32), array(0.3480342, dtype=float32)]
# Epoch: 1, Batch: 156, D Loss: 0.3472980260848999, G Loss: [array(0.34691238, dtype=float32), array(0.34691238, dtype=float32), array(0.34691238, dtype=float32)]
# Epoch: 1, Batch: 157, D Loss: 0.34610500931739807, G Loss: [array(0.34561214, dtype=float32), array(0.34561214, dtype=float32), array(0.34561214, dtype=float32)]
# Epoch: 1, Batch: 158, D Loss: 0.34498995542526245, G Loss: [array(0.34448135, dtype=float32), array(0.34448135, dtype=float32), array(0.34448135, dtype=float32)]
# Epoch: 1, Batch: 159, D Loss: 0.3439021110534668, G Loss: [array(0.34342617, dtype=float32), array(0.34342617, dtype=float32), array(0.34342617, dtype=float32)]
# Epoch: 1, Batch: 160, D Loss: 0.34262770414352417, G Loss: [array(0.3421838, dtype=float32), array(0.3421838, dtype=float32), array(0.3421838, dtype=float32)]
# Epoch: 1, Batch: 161, D Loss: 0.34133288264274597, G Loss: [array(0.3408465, dtype=float32), array(0.3408465, dtype=float32), array(0.3408465, dtype=float32)]
# Epoch: 1, Batch: 162, D Loss: 0.33995723724365234, G Loss: [array(0.3394448, dtype=float32), array(0.3394448, dtype=float32), array(0.3394448, dtype=float32)]
# Epoch: 1, Batch: 163, D Loss: 0.338594913482666, G Loss: [array(0.33808127, dtype=float32), array(0.33808127, dtype=float32), array(0.33808127, dtype=float32)]
# Epoch: 1, Batch: 164, D Loss: 0.33718550205230713, G Loss: [array(0.33667564, dtype=float32), array(0.33667564, dtype=float32), array(0.33667564, dtype=float32)]
# Epoch: 1, Batch: 165, D Loss: 0.33577144145965576, G Loss: [array(0.3352662, dtype=float32), array(0.3352662, dtype=float32), array(0.3352662, dtype=float32)]
# Epoch: 1, Batch: 166, D Loss: 0.3343898057937622, G Loss: [array(0.3338897, dtype=float32), array(0.3338897, dtype=float32), array(0.3338897, dtype=float32)]
# Epoch: 1, Batch: 167, D Loss: 0.333024263381958, G Loss: [array(0.33252987, dtype=float32), array(0.33252987, dtype=float32), array(0.33252987, dtype=float32)]
# Epoch: 1, Batch: 168, D Loss: 0.33168572187423706, G Loss: [array(0.33119905, dtype=float32), array(0.33119905, dtype=float32), array(0.33119905, dtype=float32)]
# Epoch: 1, Batch: 169, D Loss: 0.3303225636482239, G Loss: [array(0.3298468, dtype=float32), array(0.3298468, dtype=float32), array(0.3298468, dtype=float32)]
# Epoch: 1, Batch: 170, D Loss: 0.32904428243637085, G Loss: [array(0.32857457, dtype=float32), array(0.32857457, dtype=float32), array(0.32857457, dtype=float32)]
# Epoch: 1, Batch: 171, D Loss: 0.3276955485343933, G Loss: [array(0.32722363, dtype=float32), array(0.32722363, dtype=float32), array(0.32722363, dtype=float32)]
# Epoch: 1, Batch: 172, D Loss: 0.3264186382293701, G Loss: [array(0.3259476, dtype=float32), array(0.3259476, dtype=float32), array(0.3259476, dtype=float32)]
# Epoch: 1, Batch: 173, D Loss: 0.3251126706600189, G Loss: [array(0.32464543, dtype=float32), array(0.32464543, dtype=float32), array(0.32464543, dtype=float32)]
# Epoch: 1, Batch: 174, D Loss: 0.32385316491127014, G Loss: [array(0.3233902, dtype=float32), array(0.3233902, dtype=float32), array(0.3233902, dtype=float32)]
# Epoch: 1, Batch: 175, D Loss: 0.3225627541542053, G Loss: [array(0.32210416, dtype=float32), array(0.32210416, dtype=float32), array(0.32210416, dtype=float32)]
# Epoch: 1, Batch: 176, D Loss: 0.32128873467445374, G Loss: [array(0.32083452, dtype=float32), array(0.32083452, dtype=float32), array(0.32083452, dtype=float32)]
# Epoch: 1, Batch: 177, D Loss: 0.3200199604034424, G Loss: [array(0.31957027, dtype=float32), array(0.31957027, dtype=float32), array(0.31957027, dtype=float32)]
# Epoch: 1, Batch: 178, D Loss: 0.3187777101993561, G Loss: [array(0.31833336, dtype=float32), array(0.31833336, dtype=float32), array(0.31833336, dtype=float32)]
# Epoch: 1, Batch: 179, D Loss: 0.3176153898239136, G Loss: [array(0.3171786, dtype=float32), array(0.3171786, dtype=float32), array(0.3171786, dtype=float32)]
# Epoch: 1, Batch: 180, D Loss: 0.31638213992118835, G Loss: [array(0.31595197, dtype=float32), array(0.31595197, dtype=float32), array(0.31595197, dtype=float32)]
# Epoch: 1, Batch: 181, D Loss: 0.31522995233535767, G Loss: [array(0.31479836, dtype=float32), array(0.31479836, dtype=float32), array(0.31479836, dtype=float32)]
# Epoch: 1, Batch: 182, D Loss: 0.3140537142753601, G Loss: [array(0.31362453, dtype=float32), array(0.31362453, dtype=float32), array(0.31362453, dtype=float32)]
# Epoch: 1, Batch: 183, D Loss: 0.3129064440727234, G Loss: [array(0.3124809, dtype=float32), array(0.3124809, dtype=float32), array(0.3124809, dtype=float32)]
# Epoch: 1, Batch: 184, D Loss: 0.31176990270614624, G Loss: [array(0.3113482, dtype=float32), array(0.3113482, dtype=float32), array(0.3113482, dtype=float32)]
# Epoch: 1, Batch: 185, D Loss: 0.31063687801361084, G Loss: [array(0.31021905, dtype=float32), array(0.31021905, dtype=float32), array(0.31021905, dtype=float32)]
# Epoch: 1, Batch: 186, D Loss: 0.30951595306396484, G Loss: [array(0.30910206, dtype=float32), array(0.30910206, dtype=float32), array(0.30910206, dtype=float32)]
# Epoch: 1, Batch: 187, D Loss: 0.308385968208313, G Loss: [array(0.30797577, dtype=float32), array(0.30797577, dtype=float32), array(0.30797577, dtype=float32)]
# Epoch: 1, Batch: 188, D Loss: 0.30727964639663696, G Loss: [array(0.30687323, dtype=float32), array(0.30687323, dtype=float32), array(0.30687323, dtype=float32)]
# Epoch: 1, Batch: 189, D Loss: 0.3061622977256775, G Loss: [array(0.30576116, dtype=float32), array(0.30576116, dtype=float32), array(0.30576116, dtype=float32)]
# Epoch: 1, Batch: 190, D Loss: 0.3050963878631592, G Loss: [array(0.30470088, dtype=float32), array(0.30470088, dtype=float32), array(0.30470088, dtype=float32)]
# Epoch: 1, Batch: 191, D Loss: 0.3040841221809387, G Loss: [array(0.3036888, dtype=float32), array(0.3036888, dtype=float32), array(0.3036888, dtype=float32)]
# Epoch: 1, Batch: 192, D Loss: 0.3030064105987549, G Loss: [array(0.30261412, dtype=float32), array(0.30261412, dtype=float32), array(0.30261412, dtype=float32)]
# Epoch: 1, Batch: 193, D Loss: 0.3019517660140991, G Loss: [array(0.30156308, dtype=float32), array(0.30156308, dtype=float32), array(0.30156308, dtype=float32)]
# Epoch: 1, Batch: 194, D Loss: 0.3009425401687622, G Loss: [array(0.3005573, dtype=float32), array(0.3005573, dtype=float32), array(0.3005573, dtype=float32)]
# Epoch: 1, Batch: 195, D Loss: 0.2998923361301422, G Loss: [array(0.29951072, dtype=float32), array(0.29951072, dtype=float32), array(0.29951072, dtype=float32)]
# Epoch: 1, Batch: 196, D Loss: 0.2988857328891754, G Loss: [array(0.29850703, dtype=float32), array(0.29850703, dtype=float32), array(0.29850703, dtype=float32)]
# Epoch: 1, Batch: 197, D Loss: 0.29788458347320557, G Loss: [array(0.29750866, dtype=float32), array(0.29750866, dtype=float32), array(0.29750866, dtype=float32)]
# Epoch: 1, Batch: 198, D Loss: 0.2968946099281311, G Loss: [array(0.29652148, dtype=float32), array(0.29652148, dtype=float32), array(0.29652148, dtype=float32)]
# Epoch: 1, Batch: 199, D Loss: 0.29591232538223267, G Loss: [array(0.29554218, dtype=float32), array(0.29554218, dtype=float32), array(0.29554218, dtype=float32)]
# Epoch: 1, Batch: 200, D Loss: 0.2949683964252472, G Loss: [array(0.29460144, dtype=float32), array(0.29460144, dtype=float32), array(0.29460144, dtype=float32)]
# Epoch: 1, Batch: 201, D Loss: 0.2940067648887634, G Loss: [array(0.29364341, dtype=float32), array(0.29364341, dtype=float32), array(0.29364341, dtype=float32)]
# Epoch: 1, Batch: 202, D Loss: 0.2930870056152344, G Loss: [array(0.29272687, dtype=float32), array(0.29272687, dtype=float32), array(0.29272687, dtype=float32)]
# Epoch: 1, Batch: 203, D Loss: 0.2921452820301056, G Loss: [array(0.29178753, dtype=float32), array(0.29178753, dtype=float32), array(0.29178753, dtype=float32)]
# Epoch: 1, Batch: 204, D Loss: 0.2911839485168457, G Loss: [array(0.29082897, dtype=float32), array(0.29082897, dtype=float32), array(0.29082897, dtype=float32)]
# Epoch: 1, Batch: 205, D Loss: 0.29025518894195557, G Loss: [array(0.28990293, dtype=float32), array(0.28990293, dtype=float32), array(0.28990293, dtype=float32)]
# Epoch: 1, Batch: 206, D Loss: 0.28935426473617554, G Loss: [array(0.28900462, dtype=float32), array(0.28900462, dtype=float32), array(0.28900462, dtype=float32)]
# Epoch: 1, Batch: 207, D Loss: 0.28841596841812134, G Loss: [array(0.2880691, dtype=float32), array(0.2880691, dtype=float32), array(0.2880691, dtype=float32)]
# Epoch: 1, Batch: 208, D Loss: 0.28751447796821594, G Loss: [array(0.2871703, dtype=float32), array(0.2871703, dtype=float32), array(0.2871703, dtype=float32)]
# Epoch: 1, Batch: 209, D Loss: 0.28664666414260864, G Loss: [array(0.2863051, dtype=float32), array(0.2863051, dtype=float32), array(0.2863051, dtype=float32)]
# Epoch: 1, Batch: 210, D Loss: 0.2857735753059387, G Loss: [array(0.2854346, dtype=float32), array(0.2854346, dtype=float32), array(0.2854346, dtype=float32)]
# Epoch: 1, Batch: 211, D Loss: 0.2848489284515381, G Loss: [array(0.2845127, dtype=float32), array(0.2845127, dtype=float32), array(0.2845127, dtype=float32)]
# Epoch: 1, Batch: 212, D Loss: 0.28399014472961426, G Loss: [array(0.2836566, dtype=float32), array(0.2836566, dtype=float32), array(0.2836566, dtype=float32)]
# Epoch: 1, Batch: 213, D Loss: 0.2831389904022217, G Loss: [array(0.28280798, dtype=float32), array(0.28280798, dtype=float32), array(0.28280798, dtype=float32)]
# Epoch: 1, Batch: 214, D Loss: 0.2822815179824829, G Loss: [array(0.281953, dtype=float32), array(0.281953, dtype=float32), array(0.281953, dtype=float32)]
# Epoch: 1, Batch: 215, D Loss: 0.28141024708747864, G Loss: [array(0.28108424, dtype=float32), array(0.28108424, dtype=float32), array(0.28108424, dtype=float32)]
# Epoch: 1, Batch: 216, D Loss: 0.28056153655052185, G Loss: [array(0.280238, dtype=float32), array(0.280238, dtype=float32), array(0.280238, dtype=float32)]
# Epoch: 1, Batch: 217, D Loss: 0.2797352075576782, G Loss: [array(0.27941412, dtype=float32), array(0.27941412, dtype=float32), array(0.27941412, dtype=float32)]
# Epoch: 1, Batch: 218, D Loss: 0.2789214253425598, G Loss: [array(0.27860272, dtype=float32), array(0.27860272, dtype=float32), array(0.27860272, dtype=float32)]
# Epoch: 1, Batch: 219, D Loss: 0.2781265377998352, G Loss: [array(0.27781022, dtype=float32), array(0.27781022, dtype=float32), array(0.27781022, dtype=float32)]
# Epoch: 1, Batch: 220, D Loss: 0.27734375, G Loss: [array(0.27702978, dtype=float32), array(0.27702978, dtype=float32), array(0.27702978, dtype=float32)]
# Epoch: 1, Batch: 221, D Loss: 0.2765420973300934, G Loss: [array(0.27623045, dtype=float32), array(0.27623045, dtype=float32), array(0.27623045, dtype=float32)]
# Epoch: 1, Batch: 222, D Loss: 0.27574819326400757, G Loss: [array(0.2754389, dtype=float32), array(0.2754389, dtype=float32), array(0.2754389, dtype=float32)]
# Epoch: 1, Batch: 223, D Loss: 0.27495795488357544, G Loss: [array(0.274651, dtype=float32), array(0.274651, dtype=float32), array(0.274651, dtype=float32)]
# Epoch: 1, Batch: 224, D Loss: 0.27421900629997253, G Loss: [array(0.2739142, dtype=float32), array(0.2739142, dtype=float32), array(0.2739142, dtype=float32)]
# Epoch: 1, Batch: 225, D Loss: 0.2734655439853668, G Loss: [array(0.27316278, dtype=float32), array(0.27316278, dtype=float32), array(0.27316278, dtype=float32)]
# Epoch: 1, Batch: 226, D Loss: 0.2726885974407196, G Loss: [array(0.27238798, dtype=float32), array(0.27238798, dtype=float32), array(0.27238798, dtype=float32)]
# Epoch: 1, Batch: 227, D Loss: 0.27193838357925415, G Loss: [array(0.2716399, dtype=float32), array(0.2716399, dtype=float32), array(0.2716399, dtype=float32)]
# Epoch: 1, Batch: 228, D Loss: 0.2711940407752991, G Loss: [array(0.2708977, dtype=float32), array(0.2708977, dtype=float32), array(0.2708977, dtype=float32)]
# Epoch: 1, Batch: 229, D Loss: 0.2704411745071411, G Loss: [array(0.2701469, dtype=float32), array(0.2701469, dtype=float32), array(0.2701469, dtype=float32)]
# Epoch: 1, Batch: 230, D Loss: 0.26967769861221313, G Loss: [array(0.26938555, dtype=float32), array(0.26938555, dtype=float32), array(0.26938555, dtype=float32)]
# Epoch: 1, Batch: 231, D Loss: 0.2689328193664551, G Loss: [array(0.26864272, dtype=float32), array(0.26864272, dtype=float32), array(0.26864272, dtype=float32)]
# Epoch: 1, Batch: 232, D Loss: 0.2681933045387268, G Loss: [array(0.26790527, dtype=float32), array(0.26790527, dtype=float32), array(0.26790527, dtype=float32)]
# Epoch: 1, Batch: 233, D Loss: 0.26749056577682495, G Loss: [array(0.2672045, dtype=float32), array(0.2672045, dtype=float32), array(0.2672045, dtype=float32)]
# Epoch: 1, Batch: 234, D Loss: 0.2667677700519562, G Loss: [array(0.2664837, dtype=float32), array(0.2664837, dtype=float32), array(0.2664837, dtype=float32)]
# Epoch: 1, Batch: 235, D Loss: 0.2660793364048004, G Loss: [array(0.2657972, dtype=float32), array(0.2657972, dtype=float32), array(0.2657972, dtype=float32)]
# Epoch: 1, Batch: 236, D Loss: 0.2653909921646118, G Loss: [array(0.26511076, dtype=float32), array(0.26511076, dtype=float32), array(0.26511076, dtype=float32)]
# Epoch: 1, Batch: 237, D Loss: 0.2647131085395813, G Loss: [array(0.26443478, dtype=float32), array(0.26443478, dtype=float32), array(0.26443478, dtype=float32)]
# Epoch: 1, Batch: 238, D Loss: 0.26398998498916626, G Loss: [array(0.26371363, dtype=float32), array(0.26371363, dtype=float32), array(0.26371363, dtype=float32)]
# Epoch: 1, Batch: 239, D Loss: 0.2633029818534851, G Loss: [array(0.26302853, dtype=float32), array(0.26302853, dtype=float32), array(0.26302853, dtype=float32)]
# Epoch: 1, Batch: 240, D Loss: 0.26265981793403625, G Loss: [array(0.26238716, dtype=float32), array(0.26238716, dtype=float32), array(0.26238716, dtype=float32)]
# Epoch: 1, Batch: 241, D Loss: 0.2619801163673401, G Loss: [array(0.26170924, dtype=float32), array(0.26170924, dtype=float32), array(0.26170924, dtype=float32)]
# Epoch: 1, Batch: 242, D Loss: 0.26134389638900757, G Loss: [array(0.26107478, dtype=float32), array(0.26107478, dtype=float32), array(0.26107478, dtype=float32)]
# Epoch: 1, Batch: 243, D Loss: 0.2606714367866516, G Loss: [array(0.26040417, dtype=float32), array(0.26040417, dtype=float32), array(0.26040417, dtype=float32)]
# Epoch: 1, Batch: 244, D Loss: 0.25999629497528076, G Loss: [array(0.2597309, dtype=float32), array(0.2597309, dtype=float32), array(0.2597309, dtype=float32)]
# Epoch: 1, Batch: 245, D Loss: 0.2593587040901184, G Loss: [array(0.25909507, dtype=float32), array(0.25909507, dtype=float32), array(0.25909507, dtype=float32)]
# Epoch: 1, Batch: 246, D Loss: 0.258716881275177, G Loss: [array(0.25845486, dtype=float32), array(0.25845486, dtype=float32), array(0.25845486, dtype=float32)]
# Epoch: 1, Batch: 247, D Loss: 0.2580598294734955, G Loss: [array(0.25779945, dtype=float32), array(0.25779945, dtype=float32), array(0.25779945, dtype=float32)]
# Epoch: 1, Batch: 248, D Loss: 0.25742965936660767, G Loss: [array(0.25717095, dtype=float32), array(0.25717095, dtype=float32), array(0.25717095, dtype=float32)]
# Epoch: 1, Batch: 249, D Loss: 0.2567955553531647, G Loss: [array(0.2565385, dtype=float32), array(0.2565385, dtype=float32), array(0.2565385, dtype=float32)]
# Epoch: 1, Batch: 250, D Loss: 0.2561328709125519, G Loss: [array(0.25587752, dtype=float32), array(0.25587752, dtype=float32), array(0.25587752, dtype=float32)]
# Epoch: 1, Batch: 251, D Loss: 0.2555154263973236, G Loss: [array(0.25526172, dtype=float32), array(0.25526172, dtype=float32), array(0.25526172, dtype=float32)]
# Epoch: 1, Batch: 252, D Loss: 0.25487667322158813, G Loss: [array(0.25462458, dtype=float32), array(0.25462458, dtype=float32), array(0.25462458, dtype=float32)]
# Epoch: 1, Batch: 253, D Loss: 0.25429272651672363, G Loss: [array(0.2540422, dtype=float32), array(0.2540422, dtype=float32), array(0.2540422, dtype=float32)]
# Epoch: 1, Batch: 254, D Loss: 0.25367993116378784, G Loss: [array(0.25343102, dtype=float32), array(0.25343102, dtype=float32), array(0.25343102, dtype=float32)]
# Epoch: 1, Batch: 255, D Loss: 0.2531004548072815, G Loss: [array(0.2528531, dtype=float32), array(0.2528531, dtype=float32), array(0.2528531, dtype=float32)]
# Epoch: 1, Batch: 256, D Loss: 0.25249308347702026, G Loss: [array(0.25224727, dtype=float32), array(0.25224727, dtype=float32), array(0.25224727, dtype=float32)]
# Epoch: 1, Batch: 257, D Loss: 0.25190091133117676, G Loss: [array(0.25165677, dtype=float32), array(0.25165677, dtype=float32), array(0.25165677, dtype=float32)]
# Epoch: 1, Batch: 258, D Loss: 0.2513009011745453, G Loss: [array(0.2510583, dtype=float32), array(0.2510583, dtype=float32), array(0.2510583, dtype=float32)]
# Epoch: 1, Batch: 259, D Loss: 0.2507471442222595, G Loss: [array(0.25050592, dtype=float32), array(0.25050592, dtype=float32), array(0.25050592, dtype=float32)]
# Epoch: 1, Batch: 260, D Loss: 0.2501668632030487, G Loss: [array(0.24992707, dtype=float32), array(0.24992707, dtype=float32), array(0.24992707, dtype=float32)]
# Epoch: 1, Batch: 261, D Loss: 0.24957343935966492, G Loss: [array(0.24933508, dtype=float32), array(0.24933508, dtype=float32), array(0.24933508, dtype=float32)]
# Epoch: 1, Batch: 262, D Loss: 0.24899789690971375, G Loss: [array(0.248761, dtype=float32), array(0.248761, dtype=float32), array(0.248761, dtype=float32)]
# Epoch: 1, Batch: 263, D Loss: 0.24840611219406128, G Loss: [array(0.24817067, dtype=float32), array(0.24817067, dtype=float32), array(0.24817067, dtype=float32)]
# Epoch: 1, Batch: 264, D Loss: 0.24782350659370422, G Loss: [array(0.24758951, dtype=float32), array(0.24758951, dtype=float32), array(0.24758951, dtype=float32)]
# Epoch: 1, Batch: 265, D Loss: 0.24726413190364838, G Loss: [array(0.24703154, dtype=float32), array(0.24703154, dtype=float32), array(0.24703154, dtype=float32)]
# Epoch: 1, Batch: 266, D Loss: 0.24671587347984314, G Loss: [array(0.24648465, dtype=float32), array(0.24648465, dtype=float32), array(0.24648465, dtype=float32)]
# Epoch: 1, Batch: 267, D Loss: 0.2461722195148468, G Loss: [array(0.24594235, dtype=float32), array(0.24594235, dtype=float32), array(0.24594235, dtype=float32)]
# Epoch: 1, Batch: 268, D Loss: 0.24561578035354614, G Loss: [array(0.2453873, dtype=float32), array(0.2453873, dtype=float32), array(0.2453873, dtype=float32)]
# Epoch: 1, Batch: 269, D Loss: 0.24509713053703308, G Loss: [array(0.24486999, dtype=float32), array(0.24486999, dtype=float32), array(0.24486999, dtype=float32)]
# Epoch: 1, Batch: 270, D Loss: 0.24456286430358887, G Loss: [array(0.24433705, dtype=float32), array(0.24433705, dtype=float32), array(0.24433705, dtype=float32)]
# Epoch: 1, Batch: 271, D Loss: 0.24404874444007874, G Loss: [array(0.24382426, dtype=float32), array(0.24382426, dtype=float32), array(0.24382426, dtype=float32)]
# Epoch: 1, Batch: 272, D Loss: 0.2435126006603241, G Loss: [array(0.24328943, dtype=float32), array(0.24328943, dtype=float32), array(0.24328943, dtype=float32)]
# Epoch: 1, Batch: 273, D Loss: 0.242973193526268, G Loss: [array(0.24275133, dtype=float32), array(0.24275133, dtype=float32), array(0.24275133, dtype=float32)]
# Epoch: 1, Batch: 274, D Loss: 0.24244365096092224, G Loss: [array(0.24222307, dtype=float32), array(0.24222307, dtype=float32), array(0.24222307, dtype=float32)]
# Epoch: 1, Batch: 275, D Loss: 0.24192458391189575, G Loss: [array(0.24170527, dtype=float32), array(0.24170527, dtype=float32), array(0.24170527, dtype=float32)]
# Epoch: 1, Batch: 276, D Loss: 0.24142545461654663, G Loss: [array(0.24120736, dtype=float32), array(0.24120736, dtype=float32), array(0.24120736, dtype=float32)]
# Epoch: 1, Batch: 277, D Loss: 0.24091660976409912, G Loss: [array(0.24069977, dtype=float32), array(0.24069977, dtype=float32), array(0.24069977, dtype=float32)]
# Epoch: 1, Batch: 278, D Loss: 0.24044063687324524, G Loss: [array(0.240225, dtype=float32), array(0.240225, dtype=float32), array(0.240225, dtype=float32)]
# Epoch: 1, Batch: 279, D Loss: 0.2399577498435974, G Loss: [array(0.2397433, dtype=float32), array(0.2397433, dtype=float32), array(0.2397433, dtype=float32)]
# Epoch: 1, Batch: 280, D Loss: 0.23945197463035583, G Loss: [array(0.23923875, dtype=float32), array(0.23923875, dtype=float32), array(0.23923875, dtype=float32)]
# Epoch: 1, Batch: 281, D Loss: 0.23893830180168152, G Loss: [array(0.2387263, dtype=float32), array(0.2387263, dtype=float32), array(0.2387263, dtype=float32)]
# Epoch: 1, Batch: 282, D Loss: 0.23845499753952026, G Loss: [array(0.23824416, dtype=float32), array(0.23824416, dtype=float32), array(0.23824416, dtype=float32)]
# Epoch: 1, Batch: 283, D Loss: 0.2379642128944397, G Loss: [array(0.23775455, dtype=float32), array(0.23775455, dtype=float32), array(0.23775455, dtype=float32)]
# Epoch: 1, Batch: 284, D Loss: 0.23748183250427246, G Loss: [array(0.23727334, dtype=float32), array(0.23727334, dtype=float32), array(0.23727334, dtype=float32)]
# Epoch: 1, Batch: 285, D Loss: 0.236984983086586, G Loss: [array(0.23677765, dtype=float32), array(0.23677765, dtype=float32), array(0.23677765, dtype=float32)]
# Epoch: 1, Batch: 286, D Loss: 0.23647820949554443, G Loss: [array(0.23627204, dtype=float32), array(0.23627204, dtype=float32), array(0.23627204, dtype=float32)]
# Epoch: 1, Batch: 287, D Loss: 0.2360030859708786, G Loss: [array(0.23579805, dtype=float32), array(0.23579805, dtype=float32), array(0.23579805, dtype=float32)]
# Epoch: 1, Batch: 288, D Loss: 0.23553845286369324, G Loss: [array(0.23533453, dtype=float32), array(0.23533453, dtype=float32), array(0.23533453, dtype=float32)]
# Epoch: 1, Batch: 289, D Loss: 0.23507115244865417, G Loss: [array(0.23486833, dtype=float32), array(0.23486833, dtype=float32), array(0.23486833, dtype=float32)]
# Epoch: 1, Batch: 290, D Loss: 0.23461201786994934, G Loss: [array(0.23441029, dtype=float32), array(0.23441029, dtype=float32), array(0.23441029, dtype=float32)]
# ...
# Epoch: 2, Batch: 165, D Loss: 0.16141919791698456, G Loss: [array(0.16135553, dtype=float32), array(0.16135553, dtype=float32), array(0.16135553, dtype=float32)]
# Epoch: 2, Batch: 166, D Loss: 0.16132375597953796, G Loss: [array(0.16126022, dtype=float32), array(0.16126022, dtype=float32), array(0.16126022, dtype=float32)]
# Epoch: 2, Batch: 167, D Loss: 0.1612207293510437, G Loss: [array(0.16115732, dtype=float32), array(0.16115732, dtype=float32), array(0.16115732, dtype=float32)]
# Epoch: 2, Batch: 168, D Loss: 0.16111186146736145, G Loss: [array(0.1610486, dtype=float32), array(0.1610486, dtype=float32), array(0.1610486, dtype=float32)]
# Epoch: 2, Batch: 169, D Loss: 0.16101115942001343, G Loss: [array(0.16094804, dtype=float32), array(0.16094804, dtype=float32), array(0.16094804, dtype=float32)]
# Epoch: 2, Batch: 170, D Loss: 0.16091391444206238, G Loss: [array(0.16085094, dtype=float32), array(0.16085094, dtype=float32), array(0.16085094, dtype=float32)]
# Epoch: 2, Batch: 171, D Loss: 0.16082069277763367, G Loss: [array(0.16075785, dtype=float32), array(0.16075785, dtype=float32), array(0.16075785, dtype=float32)]
# Epoch: 2, Batch: 172, D Loss: 0.16072310507297516, G Loss: [array(0.1606604, dtype=float32), array(0.1606604, dtype=float32), array(0.1606604, dtype=float32)]
# Epoch: 2, Batch: 173, D Loss: 0.16063037514686584, G Loss: [array(0.1605678, dtype=float32), array(0.1605678, dtype=float32), array(0.1605678, dtype=float32)]
# Epoch: 2, Batch: 174, D Loss: 0.16053131222724915, G Loss: [array(0.16046888, dtype=float32), array(0.16046888, dtype=float32), array(0.16046888, dtype=float32)]
# Epoch: 2, Batch: 175, D Loss: 0.16043239831924438, G Loss: [array(0.16037011, dtype=float32), array(0.16037011, dtype=float32), array(0.16037011, dtype=float32)]
# Epoch: 2, Batch: 176, D Loss: 0.16034017503261566, G Loss: [array(0.160278, dtype=float32), array(0.160278, dtype=float32), array(0.160278, dtype=float32)]
# Epoch: 2, Batch: 177, D Loss: 0.1602427363395691, G Loss: [array(0.1601807, dtype=float32), array(0.1601807, dtype=float32), array(0.1601807, dtype=float32)]
# Epoch: 2, Batch: 178, D Loss: 0.16015483438968658, G Loss: [array(0.16009292, dtype=float32), array(0.16009292, dtype=float32), array(0.16009292, dtype=float32)]
# Epoch: 2, Batch: 179, D Loss: 0.16005295515060425, G Loss: [array(0.15999117, dtype=float32), array(0.15999117, dtype=float32), array(0.15999117, dtype=float32)]
# Epoch: 2, Batch: 180, D Loss: 0.1599712073802948, G Loss: [array(0.15990956, dtype=float32), array(0.15990956, dtype=float32), array(0.15990956, dtype=float32)]
# Epoch: 2, Batch: 181, D Loss: 0.15988026559352875, G Loss: [array(0.15981875, dtype=float32), array(0.15981875, dtype=float32), array(0.15981875, dtype=float32)]
# Epoch: 2, Batch: 182, D Loss: 0.15978553891181946, G Loss: [array(0.15972415, dtype=float32), array(0.15972415, dtype=float32), array(0.15972415, dtype=float32)]
# Epoch: 2, Batch: 183, D Loss: 0.1596883237361908, G Loss: [array(0.15962707, dtype=float32), array(0.15962707, dtype=float32), array(0.15962707, dtype=float32)]
# Epoch: 2, Batch: 184, D Loss: 0.15958639979362488, G Loss: [array(0.15952529, dtype=float32), array(0.15952529, dtype=float32), array(0.15952529, dtype=float32)]
# Epoch: 2, Batch: 185, D Loss: 0.15949609875679016, G Loss: [array(0.1594351, dtype=float32), array(0.1594351, dtype=float32), array(0.1594351, dtype=float32)]
# Epoch: 2, Batch: 186, D Loss: 0.15940234065055847, G Loss: [array(0.15934148, dtype=float32), array(0.15934148, dtype=float32), array(0.15934148, dtype=float32)]
# Epoch: 2, Batch: 187, D Loss: 0.15930292010307312, G Loss: [array(0.15924218, dtype=float32), array(0.15924218, dtype=float32), array(0.15924218, dtype=float32)]
# Epoch: 2, Batch: 188, D Loss: 0.15920811891555786, G Loss: [array(0.15914752, dtype=float32), array(0.15914752, dtype=float32), array(0.15914752, dtype=float32)]
# Epoch: 2, Batch: 189, D Loss: 0.1591138243675232, G Loss: [array(0.15905336, dtype=float32), array(0.15905336, dtype=float32), array(0.15905336, dtype=float32)]
# Epoch: 2, Batch: 190, D Loss: 0.1590208262205124, G Loss: [array(0.15896048, dtype=float32), array(0.15896048, dtype=float32), array(0.15896048, dtype=float32)]
# Epoch: 2, Batch: 191, D Loss: 0.15893706679344177, G Loss: [array(0.15887685, dtype=float32), array(0.15887685, dtype=float32), array(0.15887685, dtype=float32)]
# Epoch: 2, Batch: 192, D Loss: 0.15883876383304596, G Loss: [array(0.15877867, dtype=float32), array(0.15877867, dtype=float32), array(0.15877867, dtype=float32)]
# Epoch: 2, Batch: 193, D Loss: 0.15875211358070374, G Loss: [array(0.15869214, dtype=float32), array(0.15869214, dtype=float32), array(0.15869214, dtype=float32)]
# Epoch: 2, Batch: 194, D Loss: 0.15866243839263916, G Loss: [array(0.15860258, dtype=float32), array(0.15860258, dtype=float32), array(0.15860258, dtype=float32)]
# Epoch: 2, Batch: 195, D Loss: 0.15857547521591187, G Loss: [array(0.15851575, dtype=float32), array(0.15851575, dtype=float32), array(0.15851575, dtype=float32)]
# Epoch: 2, Batch: 196, D Loss: 0.15848881006240845, G Loss: [array(0.15842922, dtype=float32), array(0.15842922, dtype=float32), array(0.15842922, dtype=float32)]
# Epoch: 2, Batch: 197, D Loss: 0.15839968621730804, G Loss: [array(0.1583402, dtype=float32), array(0.1583402, dtype=float32), array(0.1583402, dtype=float32)]
# Epoch: 2, Batch: 198, D Loss: 0.15830275416374207, G Loss: [array(0.15824339, dtype=float32), array(0.15824339, dtype=float32), array(0.15824339, dtype=float32)]
# Epoch: 2, Batch: 199, D Loss: 0.15821217000484467, G Loss: [array(0.15815294, dtype=float32), array(0.15815294, dtype=float32), array(0.15815294, dtype=float32)]
# Epoch: 2, Batch: 200, D Loss: 0.15813606977462769, G Loss: [array(0.15807696, dtype=float32), array(0.15807696, dtype=float32), array(0.15807696, dtype=float32)]
# Epoch: 2, Batch: 201, D Loss: 0.15804657340049744, G Loss: [array(0.15798758, dtype=float32), array(0.15798758, dtype=float32), array(0.15798758, dtype=float32)]
# Epoch: 2, Batch: 202, D Loss: 0.15796081721782684, G Loss: [array(0.15790194, dtype=float32), array(0.15790194, dtype=float32), array(0.15790194, dtype=float32)]
# Epoch: 2, Batch: 203, D Loss: 0.15787924826145172, G Loss: [array(0.1578205, dtype=float32), array(0.1578205, dtype=float32), array(0.1578205, dtype=float32)]
# Epoch: 2, Batch: 204, D Loss: 0.1577913463115692, G Loss: [array(0.15773271, dtype=float32), array(0.15773271, dtype=float32), array(0.15773271, dtype=float32)]
# Epoch: 2, Batch: 205, D Loss: 0.15770235657691956, G Loss: [array(0.15764385, dtype=float32), array(0.15764385, dtype=float32), array(0.15764385, dtype=float32)]
# Epoch: 2, Batch: 206, D Loss: 0.1576225459575653, G Loss: [array(0.15756415, dtype=float32), array(0.15756415, dtype=float32), array(0.15756415, dtype=float32)]
# Epoch: 2, Batch: 207, D Loss: 0.1575331836938858, G Loss: [array(0.1574749, dtype=float32), array(0.1574749, dtype=float32), array(0.1574749, dtype=float32)]
# Epoch: 2, Batch: 208, D Loss: 0.15745270252227783, G Loss: [array(0.15739453, dtype=float32), array(0.15739453, dtype=float32), array(0.15739453, dtype=float32)]
# Epoch: 2, Batch: 209, D Loss: 0.15736225247383118, G Loss: [array(0.15730421, dtype=float32), array(0.15730421, dtype=float32), array(0.15730421, dtype=float32)]
# Epoch: 2, Batch: 210, D Loss: 0.15726938843727112, G Loss: [array(0.15721147, dtype=float32), array(0.15721147, dtype=float32), array(0.15721147, dtype=float32)]
# Epoch: 2, Batch: 211, D Loss: 0.15718555450439453, G Loss: [array(0.15712777, dtype=float32), array(0.15712777, dtype=float32), array(0.15712777, dtype=float32)]
# Epoch: 2, Batch: 212, D Loss: 0.15709856152534485, G Loss: [array(0.15704086, dtype=float32), array(0.15704086, dtype=float32), array(0.15704086, dtype=float32)]
# Epoch: 2, Batch: 213, D Loss: 0.15701785683631897, G Loss: [array(0.15696028, dtype=float32), array(0.15696028, dtype=float32), array(0.15696028, dtype=float32)]
# Epoch: 2, Batch: 214, D Loss: 0.15692628920078278, G Loss: [array(0.15686883, dtype=float32), array(0.15686883, dtype=float32), array(0.15686883, dtype=float32)]
# Epoch: 2, Batch: 215, D Loss: 0.15683797001838684, G Loss: [array(0.15678062, dtype=float32), array(0.15678062, dtype=float32), array(0.15678062, dtype=float32)]
# Epoch: 2, Batch: 216, D Loss: 0.1567496955394745, G Loss: [array(0.15669246, dtype=float32), array(0.15669246, dtype=float32), array(0.15669246, dtype=float32)]
# Epoch: 2, Batch: 217, D Loss: 0.15666623413562775, G Loss: [array(0.15660912, dtype=float32), array(0.15660912, dtype=float32), array(0.15660912, dtype=float32)]
# Epoch: 2, Batch: 218, D Loss: 0.156585693359375, G Loss: [array(0.1565287, dtype=float32), array(0.1565287, dtype=float32), array(0.1565287, dtype=float32)]
# Epoch: 2, Batch: 219, D Loss: 0.1565059870481491, G Loss: [array(0.1564491, dtype=float32), array(0.1564491, dtype=float32), array(0.1564491, dtype=float32)]
# Epoch: 2, Batch: 220, D Loss: 0.15642067790031433, G Loss: [array(0.15636393, dtype=float32), array(0.15636393, dtype=float32), array(0.15636393, dtype=float32)]
# Epoch: 2, Batch: 221, D Loss: 0.15634557604789734, G Loss: [array(0.1562889, dtype=float32), array(0.1562889, dtype=float32), array(0.1562889, dtype=float32)]
# Epoch: 2, Batch: 222, D Loss: 0.15626278519630432, G Loss: [array(0.15620624, dtype=float32), array(0.15620624, dtype=float32), array(0.15620624, dtype=float32)]
# Epoch: 2, Batch: 223, D Loss: 0.15618763864040375, G Loss: [array(0.15613125, dtype=float32), array(0.15613125, dtype=float32), array(0.15613125, dtype=float32)]
# Epoch: 2, Batch: 224, D Loss: 0.15611328184604645, G Loss: [array(0.15605694, dtype=float32), array(0.15605694, dtype=float32), array(0.15605694, dtype=float32)]
# Epoch: 2, Batch: 225, D Loss: 0.15603598952293396, G Loss: [array(0.15597977, dtype=float32), array(0.15597977, dtype=float32), array(0.15597977, dtype=float32)]
# Epoch: 2, Batch: 226, D Loss: 0.15595614910125732, G Loss: [array(0.15590003, dtype=float32), array(0.15590003, dtype=float32), array(0.15590003, dtype=float32)]
# Epoch: 2, Batch: 227, D Loss: 0.15587283670902252, G Loss: [array(0.15581691, dtype=float32), array(0.15581691, dtype=float32), array(0.15581691, dtype=float32)]
# Epoch: 2, Batch: 228, D Loss: 0.1557869166135788, G Loss: [array(0.1557319, dtype=float32), array(0.1557319, dtype=float32), array(0.1557319, dtype=float32)]
# Epoch: 2, Batch: 229, D Loss: 0.15571001172065735, G Loss: [array(0.15565422, dtype=float32), array(0.15565422, dtype=float32), array(0.15565422, dtype=float32)]
# Epoch: 2, Batch: 230, D Loss: 0.1558704376220703, G Loss: [array(0.15581468, dtype=float32), array(0.15581468, dtype=float32), array(0.15581468, dtype=float32)]
# Epoch: 2, Batch: 231, D Loss: 0.15603835880756378, G Loss: [array(0.1561844, dtype=float32), array(0.1561844, dtype=float32), array(0.1561844, dtype=float32)]
# Epoch: 2, Batch: 232, D Loss: 0.15625378489494324, G Loss: [array(0.15619804, dtype=float32), array(0.15619804, dtype=float32), array(0.15619804, dtype=float32)]
# Epoch: 2, Batch: 233, D Loss: 0.1603383719921112, G Loss: [array(0.16028126, dtype=float32), array(0.16028126, dtype=float32), array(0.16028126, dtype=float32)]
# Epoch: 2, Batch: 234, D Loss: 0.16039356589317322, G Loss: [array(0.16036013, dtype=float32), array(0.16036013, dtype=float32), array(0.16036013, dtype=float32)]
# Epoch: 2, Batch: 235, D Loss: 0.161850243806839, G Loss: [array(0.16301844, dtype=float32), array(0.16301844, dtype=float32), array(0.16301844, dtype=float32)]
# Epoch: 2, Batch: 236, D Loss: 0.1632300168275833, G Loss: [array(0.16317211, dtype=float32), array(0.16317211, dtype=float32), array(0.16317211, dtype=float32)]
# Epoch: 2, Batch: 237, D Loss: 0.16318491101264954, G Loss: [array(0.1631271, dtype=float32), array(0.1631271, dtype=float32), array(0.1631271, dtype=float32)]
# Epoch: 2, Batch: 238, D Loss: 0.16311924159526825, G Loss: [array(0.16306154, dtype=float32), array(0.16306154, dtype=float32), array(0.16306154, dtype=float32)]
# Epoch: 2, Batch: 239, D Loss: 0.16313037276268005, G Loss: [array(0.16307275, dtype=float32), array(0.16307275, dtype=float32), array(0.16307275, dtype=float32)]
# Epoch: 2, Batch: 240, D Loss: 0.16306842863559723, G Loss: [array(0.16301091, dtype=float32), array(0.16301091, dtype=float32), array(0.16301091, dtype=float32)]
# Epoch: 2, Batch: 241, D Loss: 0.16299381852149963, G Loss: [array(0.16293642, dtype=float32), array(0.16293642, dtype=float32), array(0.16293642, dtype=float32)]
# Epoch: 2, Batch: 242, D Loss: 0.16295060515403748, G Loss: [array(0.16289328, dtype=float32), array(0.16289328, dtype=float32), array(0.16289328, dtype=float32)]
# Epoch: 2, Batch: 243, D Loss: 0.16287051141262054, G Loss: [array(0.1628133, dtype=float32), array(0.1628133, dtype=float32), array(0.1628133, dtype=float32)]
# Epoch: 2, Batch: 244, D Loss: 0.1627921313047409, G Loss: [array(0.16273503, dtype=float32), array(0.16273503, dtype=float32), array(0.16273503, dtype=float32)]
# Epoch: 2, Batch: 245, D Loss: 0.16271139681339264, G Loss: [array(0.1626544, dtype=float32), array(0.1626544, dtype=float32), array(0.1626544, dtype=float32)]
# Epoch: 2, Batch: 246, D Loss: 0.16262249648571014, G Loss: [array(0.16256562, dtype=float32), array(0.16256562, dtype=float32), array(0.16256562, dtype=float32)]
# Epoch: 2, Batch: 247, D Loss: 0.1625375747680664, G Loss: [array(0.1624808, dtype=float32), array(0.1624808, dtype=float32), array(0.1624808, dtype=float32)]
# Epoch: 2, Batch: 248, D Loss: 0.1624656617641449, G Loss: [array(0.162409, dtype=float32), array(0.162409, dtype=float32), array(0.162409, dtype=float32)]
# Epoch: 2, Batch: 249, D Loss: 0.16239623725414276, G Loss: [array(0.16233967, dtype=float32), array(0.16233967, dtype=float32), array(0.16233967, dtype=float32)]
# Epoch: 2, Batch: 250, D Loss: 0.1623465120792389, G Loss: [array(0.16229004, dtype=float32), array(0.16229004, dtype=float32), array(0.16229004, dtype=float32)]
# Epoch: 2, Batch: 251, D Loss: 0.16226422786712646, G Loss: [array(0.16220787, dtype=float32), array(0.16220787, dtype=float32), array(0.16220787, dtype=float32)]
# Epoch: 2, Batch: 252, D Loss: 0.16220179200172424, G Loss: [array(0.16214553, dtype=float32), array(0.16214553, dtype=float32), array(0.16214553, dtype=float32)]
# Epoch: 2, Batch: 253, D Loss: 0.16211071610450745, G Loss: [array(0.16205455, dtype=float32), array(0.16205455, dtype=float32), array(0.16205455, dtype=float32)]
# Epoch: 2, Batch: 254, D Loss: 0.16201825439929962, G Loss: [array(0.16196221, dtype=float32), array(0.16196221, dtype=float32), array(0.16196221, dtype=float32)]
# Epoch: 2, Batch: 255, D Loss: 0.16195130348205566, G Loss: [array(0.16189536, dtype=float32), array(0.16189536, dtype=float32), array(0.16189536, dtype=float32)]
# Epoch: 2, Batch: 256, D Loss: 0.16186736524105072, G Loss: [array(0.16181153, dtype=float32), array(0.16181153, dtype=float32), array(0.16181153, dtype=float32)]
# Epoch: 2, Batch: 257, D Loss: 0.16177575290203094, G Loss: [array(0.16172002, dtype=float32), array(0.16172002, dtype=float32), array(0.16172002, dtype=float32)]
# Epoch: 2, Batch: 258, D Loss: 0.16169297695159912, G Loss: [array(0.16163735, dtype=float32), array(0.16163735, dtype=float32), array(0.16163735, dtype=float32)]
# Epoch: 2, Batch: 259, D Loss: 0.16160714626312256, G Loss: [array(0.16155164, dtype=float32), array(0.16155164, dtype=float32), array(0.16155164, dtype=float32)]
# Epoch: 2, Batch: 260, D Loss: 0.161522775888443, G Loss: [array(0.16146736, dtype=float32), array(0.16146736, dtype=float32), array(0.16146736, dtype=float32)]
# Epoch: 2, Batch: 261, D Loss: 0.1614460051059723, G Loss: [array(0.16139069, dtype=float32), array(0.16139069, dtype=float32), array(0.16139069, dtype=float32)]
# Epoch: 2, Batch: 262, D Loss: 0.16136446595191956, G Loss: [array(0.16130927, dtype=float32), array(0.16130927, dtype=float32), array(0.16130927, dtype=float32)]
# Epoch: 2, Batch: 263, D Loss: 0.16127920150756836, G Loss: [array(0.16122411, dtype=float32), array(0.16122411, dtype=float32), array(0.16122411, dtype=float32)]

# %% [markdown]
# **Notes:**
# - Epochs parameter determines how many times the learning algorithm will work through the entire training dataset.
# - The `batch_size` is the number of samples that will be propagated through the network at a time.

# %% [markdown]
# # __Step 7: Generate New Images and Evaluate the Model's Performance__
#
# - Generate new images and evaluate the performance of the GAN.
# - Generate a random noise vector and feed it into the trained generator to create new images.

# %%
import matplotlib.pyplot as plt
# Generate random noise as an input to initialize the generator
random_noise = np.random.normal(0,1, [100, 100])

# Generate the images from the noise
generated_images = generator.predict(random_noise)

# Visualize the generated images
plt.figure(figsize=(10,10))
for i in range(generated_images.shape[0]):
    plt.subplot(10, 10, i+1)
    plt.imshow(generated_images[i, :, :, 0], cmap='gray')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 9ms/step

# %% [markdown]
# - The resulting plot shows the images generated by the GAN model.
#
# **Notes:**
#
# The output effectively demonstrates how model can generate images resembling handwritten digit 8. However, there is room for improving the quality of these images.

# %% [markdown]
# # __Conclusion__
#
# In this demo, you have successfully implemented a GAN to generate images resembling handwritten digits, focusing on the MNIST dataset. The process involved constructing and training a generator and a discriminator. The results were promising, showcasing the GAN's ability to create images similar to the digit **8**, but also highlighted the need for further improvements in image quality.
