# %%
def setup_environment():
    import sys
    sys.path.append('C:\\gitworkspace\\aimldemo\\jupyterworkapce')
    import stratup_env_setup
    stratup_env_setup.set_env()

# %%
setup_environment()

# %%
import os
from google import genai

# %%
client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

response = client.models.generate_content(
    model="gemini-2.5-pro",
    contents="Explain microservices architecture"
)

print(response.text)
# Out:
# Of course! Here is a comprehensive explanation of microservices architecture, broken down for clarity.
#
# ### The Simple Analogy: Legos vs. a Plastic Toy
#
# Imagine you're building a spaceship.
#
# *   **Monolithic Architecture (The "Old Way"):** You are given a single, large, pre-molded plastic spaceship toy. It has a cockpit, wings, and engines, all fused together. If you want to upgrade the engines, you can't. If a wing breaks, the whole toy is broken. It's simple to start with, but impossible to change or fix in pieces.
#
# *   **Microservices Architecture:** You are given a box of Lego bricks. You build a cockpit from some bricks, wings from others, and engines from another set. Each part is a self-contained unit.
#     *   Want to upgrade the engines? Just take them off and build better ones.
#     *   Does a wing break? The rest of the spaceship is fine, and you can just fix the wing.
#     *   Need more power? Add more engine blocks without touching the cockpit.
#
# This is the core idea of microservices.
#
# ---
#
# ### What is Microservices Architecture?
#
# Microservices architecture is an architectural style that structures an application as a **collection of small, autonomous services**, modeled around business domains.
#
# Instead of building one massive, single application (a monolith), you build multiple small applications (services) that work together. Each service is:
#
# *   **Small and Focused:** It does one thing and does it well (e.g., a "User Profile Service" or a "Payment Processing Service").
# *   **Independently Deployable:** You can update, test, and deploy one service without affecting any of the others.
# *   **Loosely Coupled:** Services communicate with each other over a network using well-defined APIs (like REST or gRPC), but they don't have deep, internal dependencies on each other.
#
# #### Visualizing the Difference
#
# **1. Monolithic Architecture**
# All features (User Interface, Business Logic for Products, Orders, etc.) are in a single codebase, running as a single process, and typically connected to a single, large database.
#
# ```
# +-----------------------------------------------------+
# |                E-Commerce Application (Single Process)                 |
# | +-----------------+ +----------------+ +----------+ |
# | |  User Service   | | Product Service| |  Order   | |
# | |      Logic      | |     Logic      | |  Service | |
# | +-----------------+ +----------------+ +----------+ |
# |                                                     |
# | +-------------------------------------------------+ |
# | |                  Single Database                | |
# | +-------------------------------------------------+ |
# +-----------------------------------------------------+
# ```
#
# **2. Microservices Architecture**
# Each feature is its own independent service, with its own code, its own process, and often its own database. They talk to each other over the network.
#
# ```
# +-----------------+      +--------------------+      +-----------------+
# |  User Service   |      |   Product Service  |      |   Order Service |
# | (Own Process)   |      |   (Own Process)    |      |   (Own Process) |
# | +-------------+ |      | +----------------+ |      | +-------------+ |
# | | User DB     | | <--> | | Product DB     | | <--> | | Order DB    | |
# | +-------------+ |      | +----------------+ |      | +-------------+ |
# +-----------------+      +--------------------+      +-----------------+
#         ^                        ^                           ^
#         |                        |                           |
#         +------------------------+---------------------------+
#                                  |
#                           API Gateway / UI
# ```
#
# ---
#
# ### Core Characteristics and Principles
#
# 1.  **Single Responsibility Principle:** Each service is responsible for a single part of the application's functionality, a "bounded context." For an e-commerce site, this might be `User Authentication`, `Product Catalog`, `Shopping Cart`, and `Payment`.
#
# 2.  **Independent Deployment:** This is a key advantage. The team managing the `Product Catalog` can deploy updates 10 times a day without coordinating with or redeploying the `Payment` service. This leads to much faster development cycles (Continuous Integration/Continuous Deployment - CI/CD).
#
# 3.  **Decentralized Data Management:** Each microservice owns and manages its own data. The `User Service` has its own database with user information, and no other service is allowed to touch it directly. If the `Order Service` needs user data, it must ask the `User Service` for it via an API call.
#
# 4.  **Decentralized Governance (Tech Stack Freedom):** Since services are independent, teams can choose the best technology stack (programming language, database, tools) for their specific service. The `Recommendation Service` might be written in Python for its machine learning libraries, while the `Payment Service` might be in Java for its robust enterprise features.
#
# 5.  **Designed for Failure (Resilience):** In a distributed system, you must assume services will fail. The architecture is built with this in mind. If the `Recommendation Service` goes down, the rest of the e-commerce site should continue to function perfectly fine; users just won't see product recommendations.
#
# 6.  **Communication via APIs:** Services communicate through well-defined, versioned Application Programming Interfaces (APIs). This ensures that they remain decoupled.
#
# ---
#
# ### Benefits of Microservices
#
# 1.  **Improved Scalability:** You can scale individual services independently. If your `Product Catalog` gets a ton of traffic during a sale, you can add more instances of *just that service* without scaling the entire application. This is highly efficient and cost-effective.
#
# 2.  **Faster Time to Market:** Small, independent teams can work on their services in parallel. The ability to deploy services independently drastically speeds up release cycles.
#
# 3.  **Increased Resilience:** The failure of one service doesn't bring down the entire application (fault isolation). This creates a more robust and stable system.
#
# 4.  **Technological Freedom:** Teams can use the best tool for the job, leading to more innovation and better-suited solutions for specific problems.
#
# 5.  **Easier to Understand and Maintain:** A single service has a much smaller codebase than a giant monolith. This makes it easier for new developers to understand, work on, and maintain.
#
# 6.  **Better Team Organization:** You can structure your organization around services (Conway's Law). A small, cross-functional team can own a service from development to deployment and maintenance, fostering a strong sense of ownership.
#
# ---
#
# ### Challenges and Drawbacks
#
# Microservices are not a silver bullet. They introduce their own complexity.
#
# 1.  **Operational Complexity:** You go from managing one application to managing dozens or hundreds of services. This requires a strong DevOps culture, automation, and sophisticated monitoring and logging tools.
#
# 2.  **Distributed System Complexity:**
#     *   **Network Latency:** Services communicate over a network, which is slower and less reliable than in-process calls within a monolith.
#     *   **Data Consistency:** Ensuring data consistency across multiple databases is a major challenge. You often have to embrace "eventual consistency" rather than traditional ACID transactions.
#     *   **Fault Tolerance:** You need to implement patterns like circuit breakers and retries to handle service failures gracefully.
#
# 3.  **Testing is More Complex:** End-to-end testing requires having multiple services running and coordinating, which is much harder than testing a single application.
#
# 4.  **Service Discovery:** When one service needs to talk to another, how does it find it? You need a service discovery mechanism (like Consul or Eureka).
#
# 5.  **Increased Infrastructure Costs:** Each service may require its own database, container, and other resources, which can initially lead to higher costs.
#
# ---
#
# ### When to Use Microservices?
#
# *   **Large, complex applications** that need to evolve quickly.
# *   When you have **multiple teams** that need to work independently.
# *   For applications requiring **high scalability and resilience**.
# *   When you are **modernizing a legacy monolithic application** by breaking it apart piece by piece.
#
# ### When to AVOID Microservices?
#
# *   **Small projects, startups, and MVPs (Minimum Viable Products).** Starting with a monolith is often faster and simpler. You can always break it into microservices later if needed (this is a common pattern called "Monolith First").
# *   When your team **lacks strong DevOps and automation skills**.
# *   For applications where strong, simple transactional consistency across the entire system is the top priority.

# %%
chat = client.chats.create(
    model="gemini-2.5-pro"
)

response = chat.send_message(
    "Tell me 2 senntnces about Piscataway, NJ?"
)

print(response.text)
# Out:
# Piscataway is one of New Jersey's oldest townships, with a rich colonial history dating back to its founding in 1666. Today, it is widely known as the home of a large portion of Rutgers University, including its Busch and Livingston campuses and SHI Stadium.
